# %% [markdown]
# # Lab 1: Access Twitter Data

# %% [markdown]
# ## Introduction

# %% [markdown]
# Welcome to the first lab of the course! <br><br>
# In this lab we will farmilarize Twitter data with Pandas and visualization tools <br>
# <br><br>

# %% [markdown]
# ### Twitter API data format

# %% [markdown]
# Here is an example of how a Tweet is constructed by the Twitter API:

# %% [markdown]
# {__"created_at"__: "Thu Jul 29 13:00:00 +0000 2021", <br>
# __"id"__: 1420730832260530178, <br>
# __"id_str"__: "1420730832260530178", <br>
# __"text"__: "Our geologists have created a #3D underground model of #Munich to make #urbanPlanning more #sustainable. As a resul\u2026 https://t.co/rkj1Gd79U7", <br>
# __"truncated"__: true, <br>
# __"entities"__: {"hashtags": [{"text": "3D", "indices": [30, 33]}, {"text": "Munich", "indices": [55, 62]}, {"text": "urbanPlanning", "indices": [71, 85]}, {"text": "sustainable", "indices": [91, 103]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/rkj1Gd79U7", "expanded_url": "https://twitter.com/i/web/status/1420730832260530178", "display_url": "twitter.com/i/web/status/1\u2026", "indices": [117, 140]}]}, <br>
# __"metadata"__: {"iso_language_code": "en", "result_type": "recent"}, <br>
# __"source"__: "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>", <br>
# __"in_reply_to_status_id"__: null, <br>
# __"in_reply_to_status_id_str"__: null, <br>
# __"in_reply_to_user_id"__: null, <br>
# __"in_reply_to_user_id_str"__: null, <br>
# __"in_reply_to_screen_name"__: null, <br>
# __"user"__: {"id": 49567644, "id_str": "49567644", "name": "TU M\u00fcnchen", "screen_name": "TU_Muenchen", __"location": "M\u00fcnchen, Bayern"__, "description": "Tweets from the TUM web communications team \nhttps://t.co/xx7lj0eDvg | \nhttps://t.co/aUFYOaosFc\u2026 | \nhttps://t.co/jQcKw1ZjLC\n| Imprint: https://t.co/AFFPM5wzh2", "url": "http://t.co/3sEsDyToir", "entities": {"url": {"urls": [{"url": "http://t.co/3sEsDyToir", "expanded_url": "http://www.tum.de", "display_url": "tum.de", "indices": [0, 22]}]}, "description": {"urls": [{"url": "https://t.co/xx7lj0eDvg", "expanded_url": "http://facebook.com/TU.Muenchen", "display_url": "facebook.com/TU.Muenchen", "indices": [45, 68]}, {"url": "https://t.co/aUFYOaosFc", "expanded_url": "http://youtube.com/user/TUMuenche", "display_url": "youtube.com/user/TUMuenche", "indices": [72, 95]}, {"url": "https://t.co/jQcKw1ZjLC", "expanded_url": "http://instagram.com/tu.muenchen/", "display_url": "instagram.com/tu.muenchen/", "indices": [100, 123]}, {"url": "https://t.co/AFFPM5wzh2", "expanded_url": "http://tum.de/impressum", "display_url": "tum.de/impressum", "indices": [135, 158]}]}}, "protected": false, "followers_count": 36482, "friends_count": 413, "listed_count": 592, "created_at": "Mon Jun 22 07:40:39 +0000 2009", "favourites_count": 18, "utc_offset": null, "time_zone": null, "geo_enabled": true, "verified": false, "statuses_count": 3236, "lang": null, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "0060A4", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/879317549133041664/XE9lXzUN_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/879317549133041664/XE9lXzUN_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/49567644/1398773621", "profile_link_color": "0071BB", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "F7F6F6", "profile_text_color": "333333", "profile_use_background_image": false, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": false, "follow_request_sent": false, "notifications": false, "translator_type": "none", "withheld_in_countries": []}, <br>
# __"geo"__: null, <br>
# __"coordinates"__: null, <br>
# __"place"__: null, <br>
# __"contributors"__: null, <br>
# __"is_quote_status"__: false, <br>
# __"retweet_count"__: 0, <br>
# __"favorite_count"__: 6, <br>
# __"favorited"__: false, <br>
# __"retweeted"__: false, <br>
# __"possibly_sensitive"__: false, <br>
# __"lang"__: "en"}

# %% [markdown]
# ## Task 1: Loading the Data

# %% [markdown]
# Load the JSON data into a pandas DataFrame. Dataframe is a useful format in data analysis, it is a table with multiple rows and columns. The Pandas documentation is here: https://pandas.pydata.org/docs/getting_started/overview.html. <br>

# %%
import pandas as pd
import json

# Write code to load the JSON data into a pandas DataFrame.

# %% [markdown]
# ## Task 2: Data Inspection
#
# * Display the first five rows of the DataFrame.
# * Print the DataFrame's shape (number of rows and columns).
# * Print the summary of the DataFrame using describe() for numerical columns and info() for an overview.

# %%
# Display the first five rows of the DataFrame
df = pd.read_json("My_Dataset.json", lines=True)
df.head(5)
# Out:
#                  created_at                   id               id_str  \
# 0 2021-11-25 09:17:45+00:00  1463799055897739270  1463799055897739270
# 1 2021-11-25 09:10:06+00:00  1463797129672015874  1463797129672015874
# 2 2021-11-25 09:00:27+00:00  1463794701031686150  1463794701031686150
# 3 2021-11-25 08:24:54+00:00  1463785753994055680  1463785753994055680
# 4 2021-11-25 08:07:01+00:00  1463781255946948611  1463781255946948611
#
#                                                 text  truncated  \
# 0     @der_flow_ @daniel_weinlein Wait. Sub d ready?      False
# 1                               @Brombeerkatze Toll🥰      False
# 2  @kenfinnigan @clementplop @OReillyMedia Oh gre...      False
# 3  @MiraAmoeba @ActorToBe solo places are not che...       True
# 4  Social Media Manager (m/w/d) in #München (Fest...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
# Shape of dataframe
print(df.shape)
# Out:
# (150, 29)

# %%
# Summary statistics
df.describe()
# Out:
#                  id        id_str  in_reply_to_status_id  \
# count  1.500000e+02  1.500000e+02           1.010000e+02
# mean   1.463621e+18  1.463621e+18           1.463519e+18
# std    7.451560e+13  7.451560e+13           4.085981e+14
# min    1.463507e+18  1.463507e+18           1.459986e+18
# 25%    1.463578e+18  1.463578e+18           1.463534e+18
# 50%    1.463604e+18  1.463604e+18           1.463586e+18
# 75%    1.463628e+18  1.463628e+18           1.463614e+18
# max    1.463799e+18  1.463799e+18           1.463792e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               1.010000e+02         1.020000e+02
# mean                1.463519e+18         3.295013e+17
# std                 4.085981e+14         5.160646e+17
# min                 1.459986e+18         7.886300e+04
# 25%                 1.463534e+18         8.557333e+07
# 50%                 1.463586e+18         5.089518e+08
# 75%                 1.463614e+18         7.268248e+17
# ...

# %%
# DataFrame information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   created_at                 150 non-null    datetime64[us, UTC]
#  1   id                         150 non-null    int64
#  2   id_str                     150 non-null    int64
#  3   text                       150 non-null    str
#  4   truncated                  150 non-null    bool
#  5   entities                   150 non-null    object
#  6   metadata                   150 non-null    object
#  7   source                     150 non-null    str
#  8   in_reply_to_status_id      101 non-null    float64
#  9   in_reply_to_status_id_str  101 non-null    float64
#  10  in_reply_to_user_id        102 non-null    float64
#  11  in_reply_to_user_id_str    102 non-null    float64
#  12  in_reply_to_screen_name    102 non-null    str
# ...

# %% [markdown]
# ## Task 3: Datetime Conversion
#
# * Convert the created_at column to datetime format. And check how the new dataframe looks like.

# %%
# Convert 'created_at' to datetime
df['created_at'] = pd.to_datetime(df['created_at'])
df.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2021-11-25 09:17:45+00:00  1463799055897739270  1463799055897739270
# 1 2021-11-25 09:10:06+00:00  1463797129672015874  1463797129672015874
# 2 2021-11-25 09:00:27+00:00  1463794701031686150  1463794701031686150
# 3 2021-11-25 08:24:54+00:00  1463785753994055680  1463785753994055680
# 4 2021-11-25 08:07:01+00:00  1463781255946948611  1463781255946948611
#
#                                                 text  truncated  \
# 0     @der_flow_ @daniel_weinlein Wait. Sub d ready?      False
# 1                               @Brombeerkatze Toll🥰      False
# 2  @kenfinnigan @clementplop @OReillyMedia Oh gre...      False
# 3  @MiraAmoeba @ActorToBe solo places are not che...       True
# 4  Social Media Manager (m/w/d) in #München (Fest...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %% [markdown]
# ## Task 4: Data Manipulation
#
# * Create new columns such as year and month extracted from the created_at datetime column.
# * Count the number of tweets per month.

# %%
# Extract year from 'created_at'
df['year'] = df['created_at'].dt.year
# Extract month from 'created_at'
df['month'] = df['created_at'].dt.month
# Extract hour from 'created_at'
df['hour'] = df['created_at'].dt.hour

# %%
# Count tweets per hour with groupby
tweets_per_hour = df.groupby('hour').size().reset_index(name='tweet_count')
tweets_per_hour
# Out:
#     hour  tweet_count
# 0      2            1
# 1      3            1
# 2      4            2
# 3      5            3
# 4      6            3
# 5      7           12
# 6      8            2
# 7      9            3
# 8     13            2
# 9     14            6
# 10    15            5
# 11    16            4
# 12    17           15
# 13    18           10
# 14    19           26
# 15    20           25
# 16    21           20
# 17    22            6
# 18    23            4

# %% [markdown]
# ## Task 5: Data Visualization
#
# Use matplotlib or seaborn to plot the number of tweets over time(hourly).

# %%
import matplotlib.pyplot as plt
# Plot

df['hour'].hist(bins=24)
plt.title('Tweets per Hour')
plt.xlabel('Hour')
plt.ylabel('Count')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Task 6: Converting the dataset to a csv file

# %%
# Save dataframe to a .csv file
df.to_csv("result_lab1.csv", index=False)

# %% [markdown]
# Feel free to play with it as much as you need to get familiar with the data.
# That's it!
# Bring your questions to the lab :)
